# %% [markdown]
# # ETL Climate Forecast
# The data used here is provided by the DWD at https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/daily/ To simplyfy the task I've focused on a single location with the location ID 0178 (Dusseldorf). The Data including a large set of metadata is provided in a packed zip file. I've already unzipped it and for ease of use renamed the file name

# %%
# !wget https://raw.githubusercontent.com/spyderroque/IBM_Advance_Data_Science/main/Capstone/weather/produkt_klima_tag_19520101_20211231_01078.txt
# Out:
# Der Befehl "wget" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('produkt_klima_tag_19520101_20211231_01078.txt', sep=';')
df.head()
# Out:
#    STATIONS_ID  MESS_DATUM  QN_3    FX    FM  QN_4    RSK  RSKF    SDK  \
# 0         1078    19520101     5  19.0   7.6  -999 -999.0  -999 -999.0
# 1         1078    19520102     5  23.1   8.3  -999 -999.0  -999 -999.0
# 2         1078    19520103     5  13.1   4.6  -999 -999.0  -999 -999.0
# 3         1078    19520104     5  11.6   4.9  -999 -999.0  -999 -999.0
# 4         1078    19520105     5   6.4   2.5  -999 -999.0  -999 -999.0
#
#    SHK_TAG     NM    VPM     PM    TMK    UPM    TXK    TNK    TGK  eor
# 0     -999 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0  eor
# 1     -999 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0  eor
# 2     -999 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0  eor
# 3     -999 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0  eor
# 4     -999 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0  eor

# %%
df.dtypes
# Out:
# STATIONS_ID      int64
# MESS_DATUM       int64
# QN_3             int64
#   FX           float64
#   FM           float64
# QN_4             int64
#  RSK           float64
# RSKF             int64
#  SDK           float64
# SHK_TAG          int64
#   NM           float64
#  VPM           float64
#   PM           float64
#  TMK           float64
#  UPM           float64
#  TXK           float64
#  TNK           float64
#  TGK           float64
# eor             object
# dtype: object

# %%
df.tail()
# Out:
#        STATIONS_ID  MESS_DATUM  QN_3    FX    FM  QN_4   RSK  RSKF    SDK  \
# 25563         1078    20211227     3  10.8   5.9     3   1.0     6  1.267
# 25564         1078    20211228     3  16.8   5.8     3  14.9     6  0.100
# 25565         1078    20211229     3  10.5   5.2     3   6.2     6  0.183
# 25566         1078    20211230     3  14.1   6.5     3   0.1     6  0.000
# 25567         1078    20211231     3  12.0   5.7     3   0.0     6  1.433
#
#        SHK_TAG    NM   VPM       PM   TMK    UPM   TXK   TNK   TGK  eor
# 25563        0   7.0   8.9   995.08   6.5  92.00   8.4   3.7   3.4  eor
# 25564        0   7.1  10.4   989.38   8.7  92.58  10.8   6.6   6.1  eor
# 25565        0   7.8  11.3  1001.27   9.7  93.67  13.1   8.4   7.9  eor
# 25566        0   7.6  14.2  1010.73  13.6  90.83  15.2  11.5  10.7  eor
# 25567        0   6.9  12.6  1014.87  13.3  81.92  14.7  11.9  10.5  eor

# %%
df.drop(columns=['eor','STATIONS_ID'], inplace=True)
df.head()
# Out:
#    MESS_DATUM  QN_3    FX    FM  QN_4    RSK  RSKF    SDK  SHK_TAG     NM  \
# 0    19520101     5  19.0   7.6  -999 -999.0  -999 -999.0     -999 -999.0
# 1    19520102     5  23.1   8.3  -999 -999.0  -999 -999.0     -999 -999.0
# 2    19520103     5  13.1   4.6  -999 -999.0  -999 -999.0     -999 -999.0
# 3    19520104     5  11.6   4.9  -999 -999.0  -999 -999.0     -999 -999.0
# 4    19520105     5   6.4   2.5  -999 -999.0  -999 -999.0     -999 -999.0
#
#      VPM     PM    TMK    UPM    TXK    TNK    TGK
# 0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 1 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 2 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 3 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0
# 4 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0

# %%
df.describe()
# Out:
#          MESS_DATUM          QN_3            FX            FM          QN_4  \
# count  2.556800e+04  25568.000000  25568.000000  25568.000000  25568.000000
# mean   1.986566e+07      6.197552      8.561780      1.795412   -243.316176
# std    2.020602e+05     34.559105     46.102971     45.648415    436.262405
# min    1.952010e+07   -999.000000   -999.000000   -999.000000   -999.000000
# 25%    1.969070e+07      5.000000      7.800000      2.500000      3.000000
# 50%    1.986567e+07     10.000000     10.000000      3.600000     10.000000
# 75%    2.004070e+07     10.000000     12.900000      5.000000     10.000000
# max    2.021123e+07     10.000000     40.300000     14.400000     10.000000
#
#                 RSK          RSKF           SDK       SHK_TAG            NM  \
# count  25568.000000  25568.000000  25568.000000  25568.000000  25568.000000
# mean    -248.157290   -247.048068   -254.693465   -249.600594   -245.782498
# std      433.477571    434.110943    439.072448    432.630447    434.837514
# min     -999.000000   -999.000000   -999.000000   -999.000000   -999.000000
# 25%        0.000000      0.000000   -999.000000      0.000000      0.000000
# 50%        0.000000      0.000000      1.000000      0.000000      4.700000
# 75%        1.200000      6.000000      5.700000      0.000000      6.700000
# max       57.400000      8.000000     16.000000     27.000000      8.000000
#
#                 VPM            PM           TMK           UPM           TXK  \
# count  25568.000000  25568.000000  25568.000000  25568.000000  25568.000000
# mean    -242.129646    508.572084   -241.600066   -193.405260   -238.539252
# std      437.046214    870.360249    437.287490    465.278181    439.068515
# min     -999.000000   -999.000000   -999.000000   -999.000000   -999.000000
# 25%     -999.000000    962.275000    -14.300000   -999.000000    -10.375000
# 50%        8.000000   1007.700000      7.400000     71.000000     10.700000
# 75%       11.900000   1015.100000     14.400000     81.650000     19.000000
# max       24.000000   1042.060000     31.200000    100.000000     40.700000
#
#                 TNK           TGK
# count  25568.000000  25568.000000
# mean    -244.721316   -246.219399
# std      435.479074    434.889141
# min     -999.000000   -999.000000
# 25%      -20.125000   -999.000000
# 50%        3.800000      2.300000
# 75%       10.000000      8.300000
# max       24.900000     23.700000

# %%
df.nunique()
# Out:
# MESS_DATUM    25568
# QN_3              4
#   FX            294
#   FM            124
# QN_4              4
#  RSK            298
# RSKF              6
#  SDK            599
# SHK_TAG          27
#   NM             82
#  VPM            212
#   PM           1338
#  TMK            406
#  UPM            714
#  TXK            448
#  TNK            384
#  TGK            413
# dtype: int64

# %%
# the Date is given MESS_DATUM. as the values begin in the early 1950s (note: yyyymmdd format) I am removing everything before 1991
df91 = df[df['MESS_DATUM']>19910100]

# %%
df91.head()
# Out:
#        MESS_DATUM  QN_3    FX    FM  QN_4   RSK  RSKF   SDK  SHK_TAG    NM  \
# 14245    19910101    10  11.5   4.5    10   7.1     6   3.7        0   4.7
# 14246    19910102    10  22.0   9.2    10   3.8     6   0.0        0   7.3
# 14247    19910103    10  23.0   5.3    10   9.2     6   0.0        0   7.3
# 14248    19910104    10  15.7   6.2    10   0.4     6   4.1        0   6.3
# 14249    19910105    10  17.8   7.7    10   2.9     6   1.1        0   5.3
#
#         VPM      PM   TMK   UPM   TXK   TNK   TGK
# 14245   7.0  1010.8   4.8  82.0   6.8   2.4   1.1
# 14246  10.7   996.7  11.4  81.0  12.9   5.0   3.7
# 14247   9.6  1001.9   8.6  85.0  13.1   7.8   7.6
# 14248   7.9  1003.5   6.8  79.0   9.6   5.6   5.6
# 14249   7.1  1000.4   6.6  74.0   7.6   3.9   3.1

# %%
df91.describe()
# Out:
#          MESS_DATUM          QN_3            FX            FM          QN_4  \
# count  1.132300e+04  11323.000000  11323.000000  11323.000000  11323.000000
# mean   2.006067e+07      6.091495      6.035273     -0.717646      9.358915
# std    8.944891e+04     51.874726     69.040993     68.484887      2.019149
# min    1.991010e+07   -999.000000   -999.000000   -999.000000      3.000000
# 25%    1.998100e+07     10.000000      7.900000      2.600000     10.000000
# 50%    2.006070e+07     10.000000     10.200000      3.700000     10.000000
# 75%    2.014040e+07     10.000000     12.900000      5.100000     10.000000
# max    2.021123e+07     10.000000     40.300000     13.000000     10.000000
#
#                 RSK          RSKF           SDK       SHK_TAG            NM  \
# count  11323.000000  11323.000000  11323.000000  11323.000000  11323.000000
# mean       2.066572      4.071801      2.147734      0.112514      5.221902
# std        4.237595      2.989008     47.286290      0.991603      2.101658
# min        0.000000      0.000000   -999.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.400000      0.000000      4.000000
# 50%        0.100000      6.000000      3.200000      0.000000      5.700000
# 75%        2.300000      6.000000      7.400000      0.000000      7.000000
# max       57.400000      8.000000     16.000000     27.000000      8.000000
#
#                 VPM            PM           TMK           UPM           TXK  \
# count  11323.000000  11323.000000  11323.000000  11323.000000  11323.000000
# mean      10.185313   1011.131233     11.058350     75.216049     15.245333
# std       13.964760      9.172135      6.783016     18.451538      7.903842
# min     -999.000000    971.100000    -14.600000   -999.000000    -10.900000
# 25%        7.300000   1005.600000      6.100000     68.000000      9.200000
# 50%        9.900000   1011.500000     11.100000     77.000000     15.200000
# 75%       13.200000   1017.100000     16.200000     84.000000     21.200000
# max       23.100000   1042.060000     31.200000    100.000000     40.700000
#
#                 TNK           TGK
# count  11323.000000  11323.000000
# mean       6.736236      4.184403
# std        6.174058     23.984906
# min      -20.800000   -999.000000
# 25%        2.300000      0.200000
# 50%        7.000000      4.900000
# 75%       11.500000      9.600000
# max       24.900000     22.600000

# %%
df91.nunique()
# Out:
# MESS_DATUM    11323
# QN_3              3
#   FX            263
#   FM            117
# QN_4              2
#  RSK            272
# RSKF              4
#  SDK            598
# SHK_TAG          22
#   NM             81
#  VPM            208
#   PM           1295
#  TMK            381
#  UPM            710
#  TXK            421
#  TNK            355
#  TGK            381
# dtype: int64

# %%
column_headers = list(df91.columns)
print(column_headers)
# Out:
# ['MESS_DATUM', 'QN_3', '  FX', '  FM', 'QN_4', ' RSK', 'RSKF', ' SDK', 'SHK_TAG', '  NM', ' VPM', '  PM', ' TMK', ' UPM', ' TXK', ' TNK', ' TGK']

# %%
column_names = ['Date','Qual_wind', 'Wind_max', 'Wind_avg','Qual_precep', 'Precepitation', 'Type_of_Precipitation',
'sunshine_hours','snow_height', 'Coverage_avg', 'Vapour_p_avg', 'Air_p_avg', 'Temp_avg', 'Rel_Humid_avg', 'Temp_max_2m', 'Temp_min_2m', 'Temp_min_gnd']
column_renamed = dict(zip(column_headers, column_names))

# %%
df91.rename(columns=column_renamed, inplace=True)
df91.head(1)
# Out:
# C:\Users\sager\AppData\Local\Temp\ipykernel_6664\584781375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df91.rename(columns=column_renamed, inplace=True)
#            Date  Qual_wind  Wind_max  Wind_avg  Qual_precep  Precepitation  \
# 14245  19910101         10      11.5       4.5           10            7.1
#
#        Type_of_Precipitation  sunshine_hours  snow_height  Coverage_avg  \
# 14245                      6             3.7            0           4.7
#
#        Vapour_p_avg  Air_p_avg  Temp_avg  Rel_Humid_avg  Temp_max_2m  \
# 14245           7.0     1010.8       4.8           82.0          6.8
#
#        Temp_min_2m  Temp_min_gnd
# 14245          2.4           1.1

# %%
df91.to_parquet('Climate_day_train.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\sager\OneDrive\Data Science Idee\weather\Advanced Data Science Capstone ETL.ipynb Zelle 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sager/OneDrive/Data%20Science%20Idee/weather/Advanced%20Data%20Science%20Capstone%20ETL.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df91.to_parquet('Climate_day_train.parquet')
#
# File c:\Users\sager\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File c:\Users\sager\anaconda3\lib\site-packages\pandas\core\frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
#    2750 Write a DataFrame to the binary parquet format.
#    2751
#    (...)
#    2831 >>> content = f.read()
#    2832 """
#    2833 from pandas.io.parquet import to_parquet
# -> 2835 return to_parquet(
#    2836     self,
#    2837     path,
#    2838     engine,
#    2839     compression=compression,
#    2840     index=index,
#    2841     partition_cols=partition_cols,
#    2842     storage_options=storage_options,
#    2843     **kwargs,
#    2844 )
#
# File c:\Users\sager\anaconda3\lib\site-packages\pandas\io\parquet.py:416, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     414 if isinstance(partition_cols, str):
#     415     partition_cols = [partition_cols]
# --> 416 impl = get_engine(engine)
#     418 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     420 impl.write(
#     421     df,
#     422     path_or_buf,
#    (...)
#     427     **kwargs,
#     428 )
#
# File c:\Users\sager\anaconda3\lib\site-packages\pandas\io\parquet.py:52, in get_engine(engine)
#      49         except ImportError as err:
#      50             error_msgs += "\n - " + str(err)
# ---> 52     raise ImportError(
#      53         "Unable to find a usable engine; "
#      54         "tried using: 'pyarrow', 'fastparquet'.\n"
#      55         "A suitable version of "
#      56         "pyarrow or fastparquet is required for parquet "
#      57         "support.\n"
#      58         "Trying to import the above resulted in these errors:"
#      59         f"{error_msgs}"
#      60     )
#      62 if engine == "pyarrow":
#      63     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
df91.boxplot(column= column_names[1:16], figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
axy = plt.axes(ylim=(-10,60))
df91.boxplot(column= column_names[1:10], ax=axy, figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
axy = plt.axes(ylim=(-20,110))
df91.boxplot(column= column_names[12:17], ax=axy, figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
axy = plt.axes(ylim=(950,1050))
df91.boxplot(column= column_names[11], ax=axy)
# Out:
# <AxesSubplot:>

# %%
df91.plot(y=column_names[1:4], ax = plt.axes(ylim=(-10,50)), figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df91.plot(y=column_names[4:7], ax = plt.axes(ylim=(-10,60)), figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df91.plot(x = column_names[0], y=column_names[7],kind = 'box' ,ax = plt.axes(ylim=(0,17)), figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df91.plot(y=column_names[7],kind = 'bar' ,ax = plt.axes(ylim=(0,17)), figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
ax2 = plt.axes(ylim = (0,30))
ax2.grid(axis='y')
df91.plot(y=column_names[8:11], ax = ax2, figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df91.plot(y=column_names[11], ax = plt.axes(ylim=(950,1050)), figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df91.plot(y=column_names[11], kind = 'box', ax = plt.axes(ylim=(970,1050)), figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
df91.plot(y=column_names[12:17], ax = plt.axes(ylim=(-10,100)), figsize=(20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# According to the documentation values given with -999 are values which were not recorded.
# The temperature values seems to be quite similar. **I should check, if there is a high correlation among them**

# %% [markdown]
# Vapor pressure and temperature seem to correlate, too. There seems to be also a correlation between air pressure and relative humidity, which is interesting considering, that rel. humid is a function of air temperature.

# %%
df91['Date']=df91['Date'].astype('string')
# Out:
# /tmp/wsuser/ipykernel_215/556079451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df91['Date']=df91['Date'].astype('string')

# %%
df91.dtypes
# Out:
# Date                      string
# Qual_wind                  int64
# Wind_max                 float64
# Wind_avg                 float64
# Qual_precep                int64
# Precepitation            float64
# Type_of_Precipitation      int64
# sunshine_hours           float64
# snow_height                int64
# Coverage_avg             float64
# Vapour_p_avg             float64
# Air_p_avg                float64
# Temp_avg                 float64
# Rel_Humid_avg            float64
# Temp_max_2m              float64
# Temp_min_2m              float64
# Temp_min_gnd             float64
# dtype: object

# %%
df91['Date']= pd.to_datetime(df91['Date'], format = "%Y%m%d")
df91.head()
# Out:
# C:\Users\sager\AppData\Local\Temp\ipykernel_6664\3402100033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df91['Date']= pd.to_datetime(df91['Date'], format = "%Y%m%d")
#             Date  Qual_wind  Wind_max  Wind_avg  Qual_precep  Precepitation  \
# 14245 1991-01-01         10      11.5       4.5           10            7.1
# 14246 1991-01-02         10      22.0       9.2           10            3.8
# 14247 1991-01-03         10      23.0       5.3           10            9.2
# 14248 1991-01-04         10      15.7       6.2           10            0.4
# 14249 1991-01-05         10      17.8       7.7           10            2.9
#
#        Type_of_Precipitation  sunshine_hours  snow_height  Coverage_avg  \
# 14245                      6             3.7            0           4.7
# 14246                      6             0.0            0           7.3
# 14247                      6             0.0            0           7.3
# 14248                      6             4.1            0           6.3
# 14249                      6             1.1            0           5.3
#
#        Vapour_p_avg  Air_p_avg  Temp_avg  Rel_Humid_avg  Temp_max_2m  \
# 14245           7.0     1010.8       4.8           82.0          6.8
# 14246          10.7      996.7      11.4           81.0         12.9
# 14247           9.6     1001.9       8.6           85.0         13.1
# 14248           7.9     1003.5       6.8           79.0          9.6
# 14249           7.1     1000.4       6.6           74.0          7.6
#
#        Temp_min_2m  Temp_min_gnd
# 14245          2.4           1.1
# 14246          5.0           3.7
# 14247          7.8           7.6
# 14248          5.6           5.6
# 14249          3.9           3.1

# %%
df91.tail()
# Out:
#             Date  Qual_wind  Wind_max  Wind_avg  Qual_precep  Precepitation  \
# 25563 2021-12-27          3      10.8       5.9            3            1.0
# 25564 2021-12-28          3      16.8       5.8            3           14.9
# 25565 2021-12-29          3      10.5       5.2            3            6.2
# 25566 2021-12-30          3      14.1       6.5            3            0.1
# 25567 2021-12-31          3      12.0       5.7            3            0.0
#
#        Type_of_Precipitation  sunshine_hours  snow_height  Coverage_avg  \
# 25563                      6           1.267            0           7.0
# 25564                      6           0.100            0           7.1
# 25565                      6           0.183            0           7.8
# 25566                      6           0.000            0           7.6
# 25567                      6           1.433            0           6.9
#
#        Vapour_p_avg  Air_p_avg  Temp_avg  Rel_Humid_avg  Temp_max_2m  \
# 25563           8.9     995.08       6.5          92.00          8.4
# 25564          10.4     989.38       8.7          92.58         10.8
# 25565          11.3    1001.27       9.7          93.67         13.1
# 25566          14.2    1010.73      13.6          90.83         15.2
# 25567          12.6    1014.87      13.3          81.92         14.7
#
#        Temp_min_2m  Temp_min_gnd
# 25563          3.7           3.4
# 25564          6.6           6.1
# 25565          8.4           7.9
# 25566         11.5          10.7
# 25567         11.9          10.5

# %%
df_clean = df91.drop(df91[df91['Wind_max'] == -999].index)

# %%
rows_to_drop = []
for i in column_names:
    temp = df91[df91[i] == -999].index
    rows_to_drop.extend(temp)

# %%
df_clean = df91.drop(rows_to_drop)

# %%
df_clean.describe()
# Out:
#           Qual_wind      Wind_max      Wind_avg  Qual_precep  Precepitation  \
# count  11222.000000  11222.000000  11222.000000  11222.00000   11222.000000
# mean       8.774906     10.761157      3.974791      9.35876       2.062146
# std        2.659968      4.009882      1.779277      2.01937       4.239138
# min        3.000000      2.100000      0.300000      3.00000       0.000000
# 25%       10.000000      7.900000      2.600000     10.00000       0.000000
# 50%       10.000000     10.200000      3.700000     10.00000       0.100000
# 75%       10.000000     12.900000      5.100000     10.00000       2.300000
# max       10.000000     40.300000     13.000000     10.00000      57.400000
#
#        Type_of_Precipitation  sunshine_hours   snow_height  Coverage_avg  \
# count           11222.000000    11222.000000  11222.000000  11222.000000
# mean                4.069685        4.369322      0.113527      5.221039
# std                 2.988936        4.243528      0.995998      2.101599
# min                 0.000000        0.000000      0.000000      0.000000
# 25%                 0.000000        0.400000      0.000000      4.000000
# 50%                 6.000000        3.200000      0.000000      5.700000
# 75%                 6.000000        7.400000      0.000000      7.000000
# max                 8.000000       16.000000     27.000000      8.000000
#
#        Vapour_p_avg     Air_p_avg      Temp_avg  Rel_Humid_avg   Temp_max_2m  \
# count  11222.000000  11222.000000  11222.000000   11222.000000  11222.000000
# mean      10.372233   1011.145100     11.073846      75.387749     15.262484
# std        3.885992      9.167585      6.784468      11.690102      7.906844
# min        1.600000    971.100000    -14.600000      26.000000    -10.900000
# 25%        7.300000   1005.700000      6.100000      68.000000      9.200000
# 50%        9.900000   1011.500000     11.100000      77.000000     15.200000
# 75%       13.200000   1017.100000     16.200000      84.000000     21.200000
# max       23.100000   1042.060000     31.200000     100.000000     40.700000
#
#         Temp_min_2m  Temp_min_gnd
# count  11222.000000  11222.000000
# mean       6.749314      4.727277
# std        6.175643      6.461611
# min      -20.800000    -29.200000
# 25%        2.300000      0.200000
# 50%        7.000000      5.000000
# 75%       11.500000      9.600000
# max       24.900000     22.600000

# %%
df_clean.to_csv('Climate_day_train.csv')
